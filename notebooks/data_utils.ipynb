# %%
import pandas as pd
pd.options.display.max_colwidth=500

# %%
base_dir = '../data/magpie/'
data_file = base_dir + 'MAGPIE_filtered_split_typebased.jsonl'

# %%
df_zero_shot = pd.read_json(data_file, lines=True)
df_zero_shot
# Out:
#        confidence                                            context  \
# 0        1.000000  [Please , can we close the doggy postbag for n...
# 1        0.770109  [But it 's a selfish family , I 'd say ., They...
# 2        1.000000  [And I looked behind , and he was just sitting...
# 3        1.000000  [Especially this year ., Makes me hair stand o...
# 4        1.000000  [Rather , what is needed most is a new way of ...
# ...           ...                                                ...
# 48390    0.854973  [The running of multiple sessions has been ano...
# 48391    1.000000  [you understand the process ?, Yeah , yeah, Ta...
# 48392    1.000000  [The same implications attach to the playing o...
# 48393    1.000000  [A manufacturer can work closely with its supp...
# 48394    1.000000  [That 's optimistic ., The announcement that N...
#
#       document_id                  genre     id                    idiom  \
# ...

# %%
column_subset = ['confidence', 'context', 'idiom', 'label', 'split', 'variant_type']
df_zero_shot = df_zero_shot[column_subset]
df_zero_shot
# Out:
#        confidence                                            context  \
# 0        1.000000  [Please , can we close the doggy postbag for n...
# 1        0.770109  [But it 's a selfish family , I 'd say ., They...
# 2        1.000000  [And I looked behind , and he was just sitting...
# 3        1.000000  [Especially this year ., Makes me hair stand o...
# 4        1.000000  [Rather , what is needed most is a new way of ...
# ...           ...                                                ...
# 48390    0.854973  [The running of multiple sessions has been ano...
# 48391    1.000000  [you understand the process ?, Yeah , yeah, Ta...
# 48392    1.000000  [The same implications attach to the playing o...
# 48393    1.000000  [A manufacturer can work closely with its supp...
# 48394    1.000000  [That 's optimistic ., The announcement that N...
#
#                          idiom label     split         variant_type
# 0         off the beaten track     i  training            identical
# ...

# %%
# All examples have exactly 5 sentences, so 3rd sentence is going to contain the Potentially Idiomatic Expression(PIE).
df_zero_shot['context'].map(lambda c: len(c)).value_counts()
# Out:
# 5    48395
# Name: context, dtype: int64

# %%
# Take only the sentence with PIE
df_zero_shot['sentence_0'] = df_zero_shot['context'].map(lambda ctx: ctx[2])
df_zero_shot[['sentence_0', 'idiom']]
# Out:
# /tmp/ipykernel_130986/3446658489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_zero_shot['sentence_0'] = df_zero_shot['context'].map(lambda ctx: ctx[2])

# %%
# Out:
#                                                                                                                                                                  sentence_0  \
# 0                               For example , with fell running and mountain marathons gaining in popularity , how about some ideas for safe running off the beaten track ?
# 1                                                                                                                                       I 'd keep him well in the running .
# 2                                                                                                                    He gives me the creeps , so I looked round , hmm hmm .
# 3                                                                                                                        ‘ He 's done us proud , as well,’ says Granville .
# ...
